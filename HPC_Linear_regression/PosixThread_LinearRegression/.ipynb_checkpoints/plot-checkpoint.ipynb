# %%
import matplotlib.pyplot as mtplt
import pandas as pnd

# %%
data = pnd.read_csv('dataset.csv')

# %%
data.head()
# Out:
#        x       y
# 0  72.33  116.23
# 1  65.60  125.82
# 2  82.57  146.00
# 3  80.88  137.75
# 4  82.94  149.23

# %%
mtplt.scatter(data.x, data.y)
mtplt.show()

# %%
data_guess1 = pnd.read_csv('guess1.csv')
data_guess1.head()
# Out:
#      x      y
# 0  0.0  50.55
# 1  1.0  51.95
# 2  2.0  53.35
# 3  3.0  54.75
# 4  4.0  56.15

# %%
mtplt.scatter(data_guess1.x,data_guess1.y)
mtplt.show()

# %%
data_guess2 = pnd.read_csv('guess2.csv')
data_guess2.head()
# Out:
#      x      y
# 0  0.0  34.67
# 1  1.0  36.17
# 2  2.0  37.67
# 3  3.0  39.17
# 4  4.0  40.67

# %%
mtplt.scatter(data_guess2.x,data_guess2.y)
mtplt.show()

# %%
data_guess3 = pnd.read_csv('guess3.csv')
data_guess3.head()
# Out:
#      x      y
# 0  0.0  13.45
# 1  1.0  14.60
# 2  2.0  15.75
# 3  3.0  16.90
# 4  4.0  18.05

# %%
mtplt.scatter(data_guess3.x,data_guess3.y)
mtplt.show()

# %%
mtplt.scatter(data.x, data.y)
mtplt.plot(data_guess1.x, data_guess1.y,c="black")
mtplt.plot(data_guess2.x, data_guess2.y, c="indigo")
mtplt.plot(data_guess3.x, data_guess3.y, c="green")
mtplt.show()

# %%
data_best = pnd.read_csv('best_case.csv')
data_best.head()
# Out:
#      x      y
# 0  0.0  38.17
# 1  1.0  39.38
# 2  2.0  40.59
# 3  3.0  41.80
# 4  4.0  43.01

# %%
mtplt.scatter(data.x, data.y)
mtplt.plot(data_guess1.x, data_guess1.y,c="black")
mtplt.plot(data_guess2.x, data_guess2.y, c="indigo")
mtplt.plot(data_guess3.x, data_guess3.y, c="green")
mtplt.plot(data_best.x, data_best.y, c="red") # best slope and intercept
mtplt.show()
